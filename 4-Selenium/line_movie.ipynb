# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑


# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://today.line.me/tw/v2/movie/incinemas/playing")

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

import time

# --- Selenium 反偵測設定（照你上面使用方式還原） ---
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://today.line.me/tw/v2/movie/incinemas/playing")

time.sleep(3)

# --- 第一次抓取電影列表 ---
movie_list = driver.find_elements(By.CSS_SELECTOR, ".detailListItem.movieListing-movie")
last_movie = movie_list[-1]
print(f"目前數量: {len(movie_list)}")

# --- 不斷向下滾動直到沒有新電影 ---
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)

    movie_list = driver.find_elements(By.CSS_SELECTOR, ".detailListItem.movieListing-movie")

    if last_movie == movie_list[-1]:
        break

    last_movie = movie_list[-1]
    print(f"目前數量: {len(movie_list)}")

# --- 整理所有電影資訊 ---
all_movie_info = []

for movie in movie_list:
    movie_name = movie.find_element(By.CSS_SELECTOR, ".detailListItem-details .detailListItem-titles").text
    movie_grade = movie.find_element(By.CSS_SELECTOR, ".iconInfo.detailListItem-iconInfo").text
    movie_time = movie.find_element(By.CSS_SELECTOR, ".detailListItem-status > span").text
    movie_link = movie.find_element(By.CSS_SELECTOR, ".detailListItem-bookingButton").get_attribute("href")

    all_movie_info.append({
        "name": movie_name,
        "average_grade": movie_grade,
        "time": movie_time,
        "link": movie_link
    })

# --- 印第一筆電影資訊 ---
print(all_movie_info[0])
# Out:
# 目前數量: 20
# 目前數量: 30
# 目前數量: 40
# 目前數量: 50
# 目前數量: 60
# 目前數量: 70
# 目前數量: 80
# 目前數量: 90
# 目前數量: 95
# {'name': '終極戰士：殺戮星球\nPredator: Badlands', 'average_grade': '9.1', 'time': '• 1小時47分 • 2025年11月06日上映', 'link': 'https://today.line.me/tw/v3/movie/5y7K1gV/1'}

# %%
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[10], line 71
#      69 if __name__ == "__main__":
#      70     test_url = "https://24h.pchome.com.tw/prod/DBA808-1900B1G9"  # 這裡換成你實際那個光泉牛奶的網址
# ---> 71     data = get_pchome_product(test_url)
#      72     print("抓到的資料：")
#      73     print(data)
#
# Cell In[10], line 31, in get_pchome_product(url)
#      28     brand = ""
#      30 # 完整商品名稱（上面那個大大的 H1）
# ---> 31 name = driver.find_element(
#      32     By.CSS_SELECTOR,
#      33     "h1[class*='o-prodMainName__grayDarkest']"
#      34 ).text
#      36 # 價格（你截圖那個 $899，那一行 div class='o-prodPrice__price o-prodPrice__price--xxx1700Primary'）
#      37 price = driver.find_element(
#      38     By.CSS_SELECTOR,
#      39     "div[class*='o-prodPrice__price--']"
#      40 ).text
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:233, in ErrorHandler.check_response(self, response)
#     231         alert_text = value["alert"].get("text")
#     232     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 233 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"h1[class*='o-prodMainName__grayDarkest']"}
#   (Session info: chrome=142.0.7444.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff7a6d0a235
# 	0x7ff7a6a62650
# 	0x7ff7a67f16dd
# 	0x7ff7a684a27e
# 	0x7ff7a684a58c
# 	0x7ff7a689ed77
# 	0x7ff7a689baba
# 	0x7ff7a683b0ed
# 	0x7ff7a683bf63
# 	0x7ff7a6d35d60
# 	0x7ff7a6d2fe8a
# 	0x7ff7a6d51005
# 	0x7ff7a6a7d73e
# 	0x7ff7a6a84e3f
# 	0x7ff7a6a6b7e4
# 	0x7ff7a6a6b99f
# 	0x7ff7a6a51908
# 	0x7ffdc7d1e8d7
# 	0x7ffdc954c53c
