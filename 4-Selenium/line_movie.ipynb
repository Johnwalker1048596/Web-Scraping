# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import os, json

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

star_mapping = {
    "M12 18.344l-5.81 3.609c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17.077.032.138.094.17.17l2.684 6.514 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343z": 2,
    "M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zM12 6.463v9.651l3.662 2.275-.925-4.383 3.316-3.086-4.398-.443L12 6.463z": 1,
    "M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zm1.6 8.365L12 6.216l-1.72 4.173-4.549.458 3.43 3.191-.961 4.546 3.8-2.36 3.799 2.36-.96-4.546 3.429-3.191-4.548-.458z": 0
}

def get_all_comment(url):
    driver.get(url)
    driver.find_element(By.CSS_SELECTOR, 'ul.tabs-list.movie li:nth-child(3)').click()
    time.sleep(2)
    comment_cards = driver.find_elements(By.CSS_SELECTOR, ".css-hnvcda")
    comment_info = []
    for comment_card in comment_cards:
        comment_user = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemUser").text
        stars = comment_card.find_elements(By.CSS_SELECTOR, ".ratingStar path")
        comment_date = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemUser-createdTime.css-squ0i5").text
        comment = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemContent").text

        grade = 0
        # 用星星計算總分
        for star in stars:
            path_d = star.get_attribute('d')
            grade += star_mapping[path_d]

        comment_info.append({
            "comment_user": comment_user,
            "grade": grade,
            "comment_date": comment_date,
            "comment": comment
        })

    return comment_info


# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://today.line.me/tw/v2/movie/incinemas/playing")

movie_list = driver.find_elements(By.CSS_SELECTOR, ".detailListItem.movieListing-movie")
last_movie = movie_list[-1]
print(f"目前數量: {len(movie_list)}")
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    # 取得新的所有元素
    movie_list = driver.find_elements(By.CSS_SELECTOR, ".detailListItem.movieListing-movie")
    if last_movie == movie_list[-1]:
        break
    
    last_movie = movie_list[-1]
    print(f"目前數量: {len(movie_list)}")

all_movie_info = []
for movie in movie_list:
    movie_name = movie.find_element(By.CSS_SELECTOR, ".detailListItem-details .detailListItem-titles").text
    movie_grade =  movie.find_element(By.CSS_SELECTOR, ".iconInfo.detailListItem-iconInfo").text
    movie_time = movie.find_element(By.CSS_SELECTOR, ".detailListItem-status > span").text
    movie_link = movie.find_element(By.CSS_SELECTOR, ".detailListItem-bookingButton").get_attribute("href")

    all_movie_info.append({
        "name": movie_name,
        "average_grade": movie_grade,
        "time": movie_time,
        "link": movie_link
    })

all_info = {}
for info in all_movie_info:
    try:
        comment_info: list = get_all_comment(info['link'])
    except Exception as e:
        with open("error_log.txt", 'a', encoding='utf-8') as f:
            f.write(f"{info['name']}-{info['link']}: {e}")
            
    all_info[info['name']] = {
        "average_grade": info['average_grade'],
        "movie_time": info['time'],
        "comments": comment_info
    }

with open(f"movie_comments.json", "w", encoding="utf-8") as f:
    json.dump(all_info, f, indent=4, ensure_ascii=False)
# Out:
# 目前數量: 20
# 目前數量: 30
# 目前數量: 40
# 目前數量: 50
# 目前數量: 60
# 目前數量: 70
# 目前數量: 80
# 目前數量: 90
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 81
#      79 for info in all_movie_info:
#      80     try:
# ---> 81         comment_info: list = get_all_comment(info['link'])
#      82     except Exception as e:
#      83         with open("error_log.txt", 'a', encoding='utf-8') as f:
#
# Cell In[2], line 19, in get_all_comment(url)
#      18 def get_all_comment(url):
# ---> 19     driver.get(url)
#      20     driver.find_element(By.CSS_SELECTOR, 'ul.tabs-list.movie li:nth-child(3)').click()
#      21     time.sleep(2)
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:483, in WebDriver.get(self, url)
#     465 def get(self, url: str) -> None:
#     466     """Navigate the browser to the specified URL in the current window or
#     467     tab.
#     468
#    (...)    481     >>> driver.get("https://example.com")
#     482     """
# --> 483     self.execute(Command.GET, {"url": url})
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:455, in WebDriver.execute(self, driver_command, params)
#     452     elif "sessionId" not in params:
#     453         params["sessionId"] = self.session_id
# --> 455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
#     458     self.error_handler.check_response(response)
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:407, in RemoteConnection.execute(self, command, params)
#     405 trimmed = self._trim_large_entries(params)
#     406 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 407 return self._request(command_info[0], url, body=data)
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:431, in RemoteConnection._request(self, method, url, body)
#     428     body = None
#     430 if self._client_config.keep_alive:
# --> 431     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     432     statuscode = response.status
#     433 else:
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)    140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\poolmanager.py:459, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     457     response = conn.urlopen(method, url, **kw)
#     458 else:
# --> 459     response = conn.urlopen(method, u.request_uri, **kw)
#     461 redirect_location = redirect and response.get_redirect_location()
#     462 if not redirect_location:
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\li599\AppData\Local\Programs\Python\Python314\Lib\socket.py:725, in SocketIO.readinto(self, b)
#     723     raise OSError("cannot read from timed out object")
#     724 try:
# --> 725     return self._sock.recv_into(b)
#     726 except timeout:
#     727     self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
print(all_movie_info[0])
# Out:
# {'name': '出神入化3\nNow You See Me：Now You Don’t', 'average_grade': '6.2', 'time': '• 1小時53分 • 2025年11月14日上映', 'link': 'https://today.line.me/tw/v3/movie/JPMx3ox/1'}
